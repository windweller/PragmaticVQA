# %% [markdown]
# # Image Captioning through QuD
#
# We first transform the dataset in a way that we can know if this project can be successful or not.
#
# We merge MSCOCO and VQA:
#
# ```
# {“Question_1”: {“cat”: [(Image_1, Caption_1), (Image_2, Caption_2)], “giraffe”: [(Image_3, Caption_3), (Image_4, Caption_4)], …}}
# ```

# %%
MSCOCO_ANNO_PATH = "/home/anie/PragmaticVQA/data/vqa/vqa2_raw/mscoco/annotations/"

import json

def load_mscoco_captions(path):
#     with open(path+"captions_train2014.json") as f:
#         train_captions = json.load(f)
    with open(path+"captions_val2014.json") as f:
        val_captions = json.load(f)
    return val_captions

# %%
val_captions = load_mscoco_captions(MSCOCO_ANNO_PATH)

# %%
len(val_captions['annotations'])
# Out:
# 202654

# %%
val_captions['annotations'][:5]
# Out:
# [{'image_id': 203564,
#   'id': 37,
#   'caption': 'A bicycle replica with a clock as the front wheel.'},
#  {'image_id': 179765,
#   'id': 38,
#   'caption': 'A black Honda motorcycle parked in front of a garage.'},
#  {'image_id': 322141,
#   'id': 49,
#   'caption': 'A room with blue walls and a white sink and door.'},
#  {'image_id': 16977,
#   'id': 89,
#   'caption': 'A car that seems to be parked illegally behind a legally parked car'},
#  {'image_id': 106140,
#   'id': 98,
#   'caption': 'A large passenger airplane flying through the air.'}]

# %%
image_ids = set()
for a in val_captions['annotations']:
    image_ids.add(a['image_id'])
len(image_ids)
# Out:
# 40504

# %%
from collections import defaultdict
image_id_to_cap = defaultdict(list)
for a in val_captions['annotations']:
    image_id_to_cap[a['image_id']].append(a['caption'])

# %%
list(image_id_to_cap.items())[:5]
# Out:
# [(203564,
#   ['A bicycle replica with a clock as the front wheel.',
#    'The bike has a clock as a tire.',
#    'A black metal bicycle with a clock inside the front wheel.',
#    'A bicycle figurine in which the front wheel is replaced with a clock\n',
#    'A clock with the appearance of the wheel of a bicycle ']),
#  (179765,
#   ['A black Honda motorcycle parked in front of a garage.',
#    'A Honda motorcycle parked in a grass driveway',
#    'A black Honda motorcycle with a dark burgundy seat.',
#    'Ma motorcycle parked on the gravel in front of a garage',
#    'A motorcycle with its brake extended standing outside']),
#  (322141,
#   ['A room with blue walls and a white sink and door.',
#    'Blue and white color scheme in a small bathroom.',
#    'This is a blue and white bathroom with a wall sink and a lifesaver on the wall.',
#    'A blue boat themed bathroom with a life preserver on the wall',
#    'A bathroom with walls that are painted baby blue.']),
#  (16977,
#   ['A car that seems to be parked illegally behind a legally parked car',
#    'two cars parked on the sidewalk on the street',
#    'City street with parked cars and a bench.',
#    'Cars try to maneuver into parking spaces along a densely packed city street. ',
#    'A couple of cars parked in a busy street sidewalk.']),
#  (106140,
#   ['A large passenger airplane flying through the air.',
#    'There is a GOL plane taking off in a partly cloudy sky.',
#    'An airplane that is, either, landing or just taking off.',
#    'An red and white airplane is in the cloudy sky.',
#    'A passenger plane taking off into the sky. '])]

# %%
val_captions['images'][:5]
# Out:
# [{'license': 3,
#   'file_name': 'COCO_val2014_000000391895.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000391895.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-14 11:18:45',
#   'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#   'id': 391895},
#  {'license': 4,
#   'file_name': 'COCO_val2014_000000522418.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000522418.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 11:38:44',
#   'flickr_url': 'http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg',
#   'id': 522418},
#  {'license': 3,
#   'file_name': 'COCO_val2014_000000184613.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000184613.jpg',
#   'height': 336,
#   'width': 500,
#   'date_captured': '2013-11-14 12:36:29',
#   'flickr_url': 'http://farm3.staticflickr.com/2169/2118578392_1193aa04a0_z.jpg',
#   'id': 184613},
#  {'license': 3,
#   'file_name': 'COCO_val2014_000000318219.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000318219.jpg',
#   'height': 640,
#   'width': 556,
#   'date_captured': '2013-11-14 13:02:53',
#   'flickr_url': 'http://farm5.staticflickr.com/4125/5094763076_813ea2751b_z.jpg',
#   'id': 318219},
#  {'license': 3,
#   'file_name': 'COCO_val2014_000000554625.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2014/COCO_val2014_000000554625.jpg',
#   'height': 640,
#   'width': 426,
#   'date_captured': '2013-11-14 16:03:19',
#   'flickr_url': 'http://farm5.staticflickr.com/4086/5094162993_8f59d8a473_z.jpg',
#   'id': 554625}]

# %%
import json
from tqdm import tqdm
from collections import defaultdict

def load_annotations(root='./data/vqa/vqa2_raw/'):
    """Annotations come from a specific format of:
    {'question_type': first few words of the question, 'multiple_choice_answer': ground truth answer, 'answers': we can ignore this,
    'image_id': image associated, 'answer_type':  "yes/no", "number", and "other",
    'question_id': number}

    This file actually does not contain real questions
    
    Keyword Arguments:
        root {str} -- root path of the data folder (default: {'./data/vqa/vqa2_raw/'})

    Return:
        {question_id: {'question_type': 'none of the above',
            'multiple_choice_answer': 'down',
            'image_id': 262148,
            'answer_type': 'other',
            'question_id': 262148000}}
    """
    anno_train_path = "annotations/v2_mscoco_train2014_annotations.json"
    anno_val_path = "annotations/v2_mscoco_val2014_annotations.json"
    
    train_anno_data = {}
    val_anno_data = {}
    for item in json.load(open(root+anno_train_path))['annotations']:
        del item['answers']
        train_anno_data[item['question_id']] = item

    for item in json.load(open(root+anno_val_path))['annotations']:
        del item['answers']
        val_anno_data[item['question_id']] = item

    return train_anno_data, val_anno_data

def load_questions(root='./data/vqa/vqa2_raw/'):
    """This file contains questions but not answers (answers are from annotations)
    We are also only dealing with MSCOCO instead of the 
    
    Keyword Arguments:
        root {str} -- root path (default: {'./data/vqa/vqa2_raw/'})

    Return:
        {question_id: {'image_id': 262148,
            'question': 'What is he on top of?',
            'question_id': 262148002}}
    """
    question_val_path = "questions/v2_OpenEnded_mscoco_val2014_questions.json"
    question_train_path = "questions/v2_OpenEnded_mscoco_train2014_questions.json"
    
    train_questions = {}
    val_questions = {}
    for item in json.load(open(root+question_train_path))['questions']:
        train_questions[item['question_id']] = item 

    for item in json.load(open(root+question_val_path))['questions']:
        val_questions[item['question_id']] = item 

    return train_questions, val_questions

# %%
train_anno_data, val_anno_data = load_annotations()
train_questions, val_questions = load_questions()

# %%
# {'Question1': {'answer1': [image_id, image_id,...]}}

# %%
val_data = {}

for q_id, question in val_questions.items():
    q = question['question']
    a = val_anno_data[q_id]['multiple_choice_answer']
    image_id = val_anno_data[q_id]['image_id']
    if q not in val_data:
        val_data[q] = defaultdict(list)
        val_data[q][a].append(image_id)
    else:
        val_data[q][a].append(image_id)

# %%
len(val_data)
# Out:
# 81565

# %%
val_data
# Out:
# {'Where is he looking?': defaultdict(list,
#              {'down': [262148, 208174], 'at camera': [43957, 388531]}),
#  'What are the people in the background doing?': defaultdict(list,
#              {'watching': [262148, 354174],
#               'talking': [464857],
#               'skateboarding': [209757],
#               'taking picture': [213978],
#               'nothing': [247234]}),
#  'What is he on top of?': defaultdict(list,
#              {'picnic table': [262148], 'chair': [477805]}),
#  'What website copyrighted the picture?': defaultdict(list,
#              {'foodiebakercom': [393225]}),
#  'Is this a creamy soup?': defaultdict(list,
#              {'no': [393225], 'yes': [484069]}),
#  'Is this rice noodle soup?': defaultdict(list,
#              {'yes': [393225], 'no': [92107]}),
#  'What is to the right of the soup?': defaultdict(list,
#              {'chopsticks': [393225], 'spoon': [327567]}),
#  'What is the man doing in the street?': defaultdict(list,
#              {'walking': [393226, 69366],
#               'squatting': [13637],
#               'riding motorcycle': [309492]}),
#  "How many photo's can you see?": defaultdict(list, {'1': [393226, 237568]}),
#  'What does the truck on the left sell?': defaultdict(list,
#              {'ice cream': [393226], 'appliances': [254789]}),
#  'Why is there a gap between the roof and wall?': defaultdict(list,
#              {'yes': [240301], 'no': [404464]}),
#  'Is it daylight in this picture?': defaultdict(list,
#              {'yes': [240301], 'no': [404464]}),
#  'Why is the cow laying down?': defaultdict(list, {'tired': [240301, 530941]}),
#  'What color is the grass in this picture?': defaultdict(list,
#              {'green': [131089], 'gray': [148911]}),
#  'Did the batter hit the ball?': defaultdict(list,
#              {'yes': [131089,
#                196885,
#                18111,
#                314704,
#                192670,
#                464087,
#                73927,
#                561745,
#                514147,
#                386821],
#               'no': [420234, 325568, 460361, 383223]}),
#  'How many are playing ball?': defaultdict(list,
#              {'1': [131089], '2': [401901]}),
#  'Is there a chain link fence in the image?': defaultdict(list,
#              {'no': [131089], 'yes': [340843]}),
#  'Is the boy playing baseball?': defaultdict(list,
#              {'yes': [131089], 'no': [348522]}),
#  'Is that a folding chair?': defaultdict(list,
#              {'no': [262162], 'yes': [102503]}),
#  'How many beds?': defaultdict(list,
#              {'1': [262162,
#                415196,
#                9857,
#                463842,
#                61717,
#                205636,
#                519316,
#                259952],
#               '2': [397512, 194885, 329080, 199783, 452179, 113836]}),
#  'What color is the bedspread?': defaultdict(list,
#              {'white': [262162, 6662, 415196, 497628, 511307, 387909],
#               'red': [395644, 437664],
#               'gray': [19888, 240637],
#               'brown': [152749, 39956, 575079],
#               'blue': [219269],
#               'green': [68277, 203455],
#               'yellow': [200725],
#               'patterned': [228418]}),
#  'How many pictures are there?': defaultdict(list,
#              {'7': [262162],
#               '25': [397681],
#               '4': [542699],
#               '2': [560332, 124102],
#               '5': [346138, 350132],
#               '16': [117337]}),
#  'Are these twin mattresses?': defaultdict(list,
#              {'no': [262162], 'yes': [199783]}),
#  'How many sources of light are there?': defaultdict(list,
#              {'1': [262162], '2': [143247]}),
#  'Is this room decorated for the 1970s?': defaultdict(list,
#              {'no': [262162], 'yes': [96539]}),
#  'Are the lights on in this room?': defaultdict(list,
#              {'no': [262162, 543631, 570659, 215622, 381037],
#               'yes': [163167, 444390, 448535, 221282, 106235]}),
#  'Are the windows big?': defaultdict(list,
#              {'yes': [262162, 526737, 228085], 'no': [441535]}),
#  'What is the chair made of?': defaultdict(list,
#              {'leather': [262162],
#               'wood': [541917, 444366, 185802],
#               'wicker': [513789]}),
#  "Is this room in someone's home?": defaultdict(list,
#              {'yes': [262162], 'no': [555905]}),
#  'Which room is this?': defaultdict(list,
#              {'bedroom': [262162,
#                8775,
#                402786,
#                10008,
#                272870,
#                144870,
#                159103,
#                555905,
#                426972,
#                9857,
#                246928,
#                578553,
#                35062,
#                348091,
#                208688,
#                380244],
#               'living room': [1138,
#                137861,
#                271820,
#                12887,
#                21465,
#                156572,
#                40018,
#                173434,
#                573320,
#                192651,
#                333888,
#                340089,
#                90239,
#                222635,
#                96402,
#                232088,
#                523212,
#                383549,
#                257370,
#                257471],
#               'office': [267175, 23575, 231991],
#               'bathroom': [5314,
#                272673,
#                10977,
#                11727,
#                69121,
#                287560,
#                27982,
#                295574,
#                301595,
#                171717,
#                41839,
#                7214,
#                175310,
#                50350,
#                182175,
#                576576,
#                55002,
#                57124,
#                162677,
#                31660,
#                193405,
#                209747,
#                213978,
#                214204,
#                345401,
#                216664,
#                350799,
#                88846,
#                354072,
#                362026,
#                243386,
#                234413,
#                110601,
#                242679,
#                242907,
#                506220,
#                117191,
#                386755,
#                256094,
#                519815],
#               'kitchen': [136466,
#                10114,
#                12326,
#                277479,
#                411564,
#                280857,
#                18918,
#                19484,
#                284365,
#                418684,
#                554523,
#                30932,
#                294595,
#                378276,
#                174258,
#                309033,
#                183249,
#                205577,
#                55544,
#                317898,
#                331268,
#                543525,
#                333998,
#                466665,
#                76176,
#                475398,
#                88634,
#                485844,
#                225312,
#                98832,
#                374115,
#                283190,
#                118378,
#                122549,
#                257458,
#                260330],
#               'laundry': [393258],
#               'restaurant': [434511],
#               'classroom': [347390],
#               'dining room': [91079]}),
#  'Is the bed white?': defaultdict(list, {'yes': [262162, 111211]}),
#  'Could this be a hotel room?': defaultdict(list,
#              {'no': [262162], 'yes': [178671]}),
#  'Is the bed made?': defaultdict(list,
#              {'yes': [262162,
#                394133,
#                546702,
#                137321,
#                269678,
#                402786,
#                405635,
#                537025,
#                146813,
#                150347,
#                413600,
#                415196,
#                159103,
#                159606,
#                555571,
#                294487,
#                294992,
#                36661,
#                246928,
#                577590,
#                437895,
#                438615,
#                575079,
#                50828,
#                313428,
#                51738,
#                61717,
#                70192,
#                333237,
#                464358,
#                494751,
#                103375,
#                103584,
#                491757,
#                497626,
#                105426,
#                240637,
#                242615,
#                521181,
#                505891,
#                244581,
#                248167,
#                518818,
#                519316,
#                388457],
#               'no': [393836,
#                533462,
#                404602,
#                145651,
#                543631,
#                283152,
#                26735,
#                167859,
#                436413,
#                437872,
#                161854,
#                448236,
#                61925,
#                65074,
#                333677,
#                205847,
#                468245,
#                469857,
#                35062,
#                100215,
#                497488,
#                499486,
#                106356,
#                243569,
#                113701,
#                118546,
#                516404,
#                516628,
#                389771]}),
#  'Are there bed headboards present in the photo?': defaultdict(list,
#              {'no': [262162], 'yes': [199783]}),
#  'Is there a mirror in the room?': defaultdict(list,
#              {'no': [262162,
#                528318,
#                270721,
#                9791,
#                291833,
#                489344,
#                358302,
#                514682],
#               'yes': [408859,
#                561088,
#                39956,
#                571839,
#                572399,
#                380487,
#                509699,
#                389445]}),
#  'What kind of room is this?': defaultdict(list,
#              {'bedroom': [262162,
#                532901,
#                537513,
#                144870,
#                543631,
#                415196,
#                432607,
#                172006,
#                173400,
#                44950,
#                317999,
#                332512,
#                464358,
#                230119,
#                522782,
#                106389,
#                111211,
#                380244,
#                516628,
#                519316,
#                521509],
#               'living room': [524822,
#                1138,
#                7570,
#                532761,
#                540962,
#                568281,
#                554154,
#                423892,
#                555048,
#                435208,
#                568710,
#                575882,
#                52132,
#                184902,
#                476597,
#                477112,
#                145101,
#                349915,
#                352286,
#                352978,
#                358833,
#                491366,
#                500118,
#                244159,
#                120747],
#               'kitchen': [262682,
#                525083,
#                802,
#                135561,
#                531499,
#                537672,
#                149298,
#                416467,
#                432886,
#                419653,
#                554523,
#                31878,
#                556178,
#                168593,
#                432150,
#                47882,
#                311879,
#                445846,
#                187001,
#                187271,
#                461030,
#                333998,
#                209145,
#                209468,
#                343466,
#                538231,
#                88562,
#                91080,
#                225312,
#                488349,
#                103538,
#                105601,
#                509807,
#                380247,
#                511430,
#                435466],
#               'library': [1342, 519479],
#               'bathroom': [264805,
#                135161,
#                1803,
#                535403,
#                536683,
#                538497,
#                538589,
#                476313,
#                151670,
#                545597,
#                24636,
#                24845,
#                156832,
#                555939,
#                295769,
#                297976,
#                430420,
#                38816,
#                171717,
#                434098,
#                435005,
#                304389,
#                567787,
#                175310,
#                308506,
#                441196,
#                574166,
#                443780,
#                575473,
#                445002,
#                581863,
#                453093,
#                59920,
#                62491,
#                463610,
#                468885,
#                211042,
#                212074,
#                476299,
#                476715,
#                538359,
#                560298,
#                480215,
#                560948,
#                93331,
#                489528,
#                98895,
#                101647,
#                103488,
#                243495,
#                103631,
#                503663,
#                504248,
#                504827,
#                507274,
#                172083,
#                246263,
#                512495,
#                382542,
#                514982,
#                517548,
#                129001,
#                523400],
#               'hospital': [409116, 72873, 345068],
#               'garage': [544522],
#               'office': [26564, 233528, 502055, 386912, 124911, 436814],
#               'restaurant': [425964],
#               'skate park': [563648],
#               'dining': [472904],
#               'conference': [83036],
#               'classroom': [480536],
#               'playroom': [357024],
#               'train station': [496765, 506085],
#               'dorm room': [105426],
#               'bar': [373748],
#               'church': [516508]}),
#  'How many chairs are in the photo?': defaultdict(list,
#              {'1': [262162],
#               '4': [294689],
#               '3': [356349, 261185],
#               '2': [375430]}),
#  'Is the desk cluttered?': defaultdict(list,
#              {'no': [262162, 402609, 433505, 130030],
#               'yes': [291981, 562628, 571313, 189997]}),
#  'Has the bed been made?': defaultdict(list,
#              {'yes': [262162, 277587, 555905, 327983, 248918],
#               'no': [556426, 469857, 367535]}),
#  'How many seats are there?': defaultdict(list,
#              {'1': [262162, 503939],
#               '2': [142620],
#               '3': [545564, 47837],
#               '8': [350988],
#               '0': [498339]}),
#  'How many frames are on the wall?': defaultdict(list,
#              {'7': [262162], '6': [36661]}),
#  'What color are the walls?': defaultdict(list,
#              {'white': [262162,
#                262605,
#                133933,
#                241174,
#                267670,
#                400552,
#                9170,
#                10966,
#                404785,
#                277197,
#                540642,
#                542145,
#                148968,
#                352584,
#                543672,
#                545101,
#                284589,
#                416467,
#                417159,
#                4296,
#                551974,
#                421433,
#                555571,
#                425035,
#                141807,
#                171717,
#                434371,
#                174258,
#                574063,
#                443652,
#                205577,
#                185512,
#                140263,
#                162156,
#                55544,
#                62491,
#                538963,
#                513789,
#                199575,
#                465295,
#                338098,
#                473849,
#                363736,
#                557135,
#                351362,
#                90839,
#                222757,
#                299457,
#                225693,
#                489257,
#                96402,
#                233140,
#                369082,
#                503663,
#                110783,
#                380244,
#                382307,
#                261115,
#                261185,
#                436814],
#               'blue': [262466,
#                10977,
#                281878,
#                419224,
#                163280,
#                290289,
#                161854,
#                353920,
#                366421,
#                126958,
#                390190],
#               'red': [711,
#                283012,
#                159500,
#                436470,
#                465327,
#                363784,
#                363830,
#                234277,
#                244665],
#               'yellow': [396461,
#                3580,
#                532761,
#                408805,
#                149184,
#                545597,
#                70921,
#                303219,
#                581415,
#                467988,
#                120648],
#               'brown': [265628,
#                21645,
#                26348,
#                428079,
#                52132,
#                52232,
#                65530,
#                483531,
#                46889],
#               'beige': [134715, 563762, 377679],
#               'green': [268670,
#                531852,
#                143370,
#                147042,
#                278966,
#                545734,
#                423165,
#                458549,
#                196789,
#                552883,
#                222635,
#                487333],
#               'tan': [24845, 227438, 384901, 521306],
#               'orange': [33650, 452359, 53569, 192403],
#               'pink': [173819, 327983, 474667, 239959, 245274],
#               'red and white': [183528],
#               'green and white': [457037],
#               'white and blue': [213978],
#               'purple': [358502, 376310],
#               'gray': [364580, 372894, 245659]}),
#  'Are there any boxes in the room?': defaultdict(list,
#              {'no': [262162], 'yes': [303534]}),
#  'Could this be a multi-purpose room?': defaultdict(list,
#              {'yes': [262162], 'no': [434098]}),
#  'What animal print does that chair resemble?': defaultdict(list,
#              {'none': [262162, 284589]}),
#  'What is behind the foot of the bed?': defaultdict(list,
#              {'chair': [262162], 'table': [238799]}),
#  'What is the size of the bed?': defaultdict(list,
#              {'queen': [262162], 'twin': [572734]}),
#  'How many pictures on the wall?': defaultdict(list,
#              {'7': [262162],
#               '0': [393836, 226119, 385633],
#               '1': [4495, 555677, 443652, 182162, 205601],
#               '2': [266117, 574145, 342819],
#               '6': [36661],
#               '20': [366421],
#               '60': [242907]}),
#  'Will this kid leave the powdered sugar on his face?': defaultdict(list,
#              {'yes': [393243, 469982]}),
#  'What is the child eating?': defaultdict(list,
#              {'donut': [393243, 469982],
#               'cake': [394940, 446359, 65883],
#               'banana': [437205, 134460],
#               'cereal': [530061],
#               'pizza': [38753, 53990],
#               'toothbrush': [174072],
#               'food': [240727]}),
#  'Is this person wearing a tie?': defaultdict(list,
#              {'no': [393243, 578492, 200381, 82157],
#               'yes': [562155, 39513, 40705, 356043, 562485]}),
#  'What color is the kids hair?': defaultdict(list,
#              {'blonde': [393243, 497438],
#               'brown': [459272],
#               'black': [280083]}),
#  "Is the man's tie purple?": defaultdict(list,
#              {'no': [262175], 'yes': [104422]}),
#  'Where was the picture taken of the man?': defaultdict(list,
#              {'forest': [262175], 'inside': [335587]}),
#  'What is the man wearing on his head?': defaultdict(list,
#              {'hat': [262175,
#                393513,
#                87489,
#                270815,
#                149912,
#                544522,
#                546222,
#                288599,
#                157928,
#                422886,
#                557564,
#                305781,
#                531929,
#                440171,
#                442565,
#                187543,
#                450400,
#                451714,
#                74332,
#                480643,
#                101053,
#                388531,
#                106344,
#                238074,
#                385877],
#               'helmet': [526778,
#                550007,
#                192701,
#                195267,
#                337375,
#                95113,
#                231343],
#               'cap': [301563],
#               'burka': [39961],
#               'goggles': [306603],
#               'sunglasses': [441453, 250155],
#               'nothing': [321804, 335587, 207458, 483476, 508101, 453799],
#               'mask': [462241],
#               'beanie': [331403, 351463],
#               'top hat': [236068],
#               'towel': [368294],
#               'hair': [370233, 564404],
#               'hood': [125129],
#               'hairnet': [522418]}),
#  'Is this a designer tie?': defaultdict(list, {'no': [262175, 104422]}),
#  'Is this photo color?': defaultdict(list, {'no': [131108], 'yes': [214527]}),
#  'Does the door open inward or outward?': defaultdict(list,
#              {'inward': [131108], 'outward': [506085]}),
#  'Is there a drainage in the pic?': defaultdict(list,
#              {'yes': [131108], 'no': [202470]}),
#  'What does the sentence on the top say?': defaultdict(list,
#              {'this is camping': [393254]}),
#  'What kind of vehicle is the RV pulling on the bottom picture?': defaultdict(list,
#              {'jeep': [393254], 'truck': [218208]}),
#  'Where is the camping tent?': defaultdict(list, {'woods': [393254]}),
#  'What color are the gym shoes?': defaultdict(list, {'white': [42]}),
#  'Is there a red sandal here?': defaultdict(list,
#              {'yes': [42], 'no': [542694]}),
#  'What color is the flip flop?': defaultdict(list, {'red': [42]}),
#  'Are there players in the dugout?': defaultdict(list, {'yes': [131115]}),
#  'Is the battery looking at the ball?': defaultdict(list,
#              {'no': [131115], 'yes': [237814]}),
#  'How many people are on the field?': defaultdict(list,
#              {'3': [131115, 544, 538414, 417857, 53081],
#               '1': [277642],
#               '9': [427135],
#               '5': [306940, 101985],
#               '6': [332930],
#               '4': [340263]}),
#  'How many signs?': defaultdict(list,
#              {'4': [262189, 406050, 151393, 179430],
#               '2': [274852, 156606, 62805, 466449, 212675, 228771],
#               '5': [292394, 310622],
#               '1': [298190, 456611]}),
#  'What color is the Salisbury Rd. sign?': defaultdict(list,
#              {'white': [262189]}),
#  'What does the last sign say?': defaultdict(list,
#              {'ross st': [262189], 'im sionstal': [11615]}),
#  'What color is the sign?': defaultdict(list,
#              {'red and yellow': [393266],
#               'red': [393583,
#                397628,
#                268755,
#                176193,
#                533217,
#                536201,
#                153207,
#                19087,
#                25378,
#                297956,
#                301300,
#                305030,
#                574242,
#                511002,
#                579893,
#                191471,
#                457133,
#                197090,
#                463633,
#                336587,
#                473121,
#                477741,
#                210766,
#                478250,
#                484029,
#                91517,
#                91619,
#                92205,
#                486162,
#                496411,
#                227134,
#                99186,
#                361830,
#                100283,
#                493682,
#                494122,
#                233963,
#                496268,
#                368080,
#                249936,
#                85529,
#                123119,
#                523194],
#               'yellow': [415325,
#                266712,
#                279714,
#                156299,
#                552156,
#                304012,
#                54967,
#                56413,
#                390569,
#                75723,
#                476936,
#                489739,
#                358707,
#                497021,
#                104829,
#                410712,
#                375914,
#                251736],
#               'orange': [397278,
#                266363,
#                397665,
#                299409,
#                561679,
#                337443,
#                495612,
#                502910],
#               'white and red': [88517, 152618],
#               'white': [140456,
#                13789,
#                13992,
#                408621,
#                16631,
#                552507,
#                292158,
#                165202,
#                38540,
#                567730,
#                45959,
#                320905,
#                322654,
#                399249,
#                196660,
#                331600,
#                75426,
#                230795,
#                231460,
#                493815,
#                234433,
#                236845],
#               'blue': [402869,
#                403104,
#                28156,
#                39628,
#                303942,
#                308459,
#                183676,
#                451373,
#                326627,
#                64495,
#                10928,
#                328084,
#                198943,
#                68838,
#                578852,
#                478868,
#                233164,
#                279209,
#                503814],
#               'green': [405104,
#                538690,
#                547047,
#                156487,
#                421673,
#                432647,
#                577712,
#                315846,
#                53956,
#                318471,
#                69911,
#                73470,
#                472387,
#                85353,
#                540176,
#                147300,
#                244184,
#                244246,
#                246348,
#                512248,
#                381842,
#                162358],
#               'black and white': [283147, 35940, 179187],
#               'red and white': [315434, 449156, 325368],
#               'black': [571834, 349579, 230976, 243896, 116096],
#               'brown': [336873, 233139, 575372],
#               'red, white and black': [347099],
#               'black and yellow': [351875],
#               'blue and white': [123239]}),
#  'Can you turn right or left in the tunnel?': defaultdict(list,
#              {'no': [393266]}),
#  'What color is the plant?': defaultdict(list,
#              {'green': [393266,
#                546674,
#                557884,
#                166166,
#                312056,
#                208971,
#                344094,
#                359855],
#               'brown': [354814]}),
#  "What color is the woman's shirt on the left?": defaultdict(list,
#              {'black': [393267], 'gray': [422700]}),
#  'What type of beverage is being displayed?': defaultdict(list,
#              {'wine': [393267], 'water': [490022]}),
#  'Why are some people wearing hats?': defaultdict(list,
#              {'nobody is wearing hats': [393267], 'yes': [378515]}),
#  'What kind of event are the people involved in?': defaultdict(list,
#              {'wine tasting': [393267], 'feeding baby': [422700]}),
#  'How many skyscrapers are there?': defaultdict(list,
#              {'2': [262197, 281827], '4': [579036, 320246], '1': [580029]}),
#  'What is the color of the building in the background?': defaultdict(list,
#              {'brown': [262197], 'white': [217517]}),
#  'Is there a tree in front of the building?': defaultdict(list,
#              {'yes': [262197], 'no': [270376]}),
#  'Is there a person riding a bike?': defaultdict(list,
#              {'no': [262197], 'yes': [138639]}),
#  'Are there lights on in the two buildings?': defaultdict(list,
#              {'yes': [262197, 132143]}),
#  'How many stories is the building on the left?': defaultdict(list,
#              {'3': [262197], '4': [426203, 440110], '17': [437303]}),
#  'Is this a hospital?': defaultdict(list,
#              {'yes': [262197, 27146, 106901, 112591, 384337],
#               'no': [873,
#                145032,
#                40051,
#                304186,
#                323598,
#                205531,
#                362599,
#                507893]}),
#  'How many umbrellas do you see?': defaultdict(list,
#              {'0': [262197, 427070, 58344],
#               '10': [405348, 49165],
#               '1': [293002, 207937],
#               '3': [576385],
#               '2': [449412, 58141],
#               '4': [461016],
#               '6': [229267]}),
#  'How many colors is the building on the right painted?': defaultdict(list,
#              {'1': [262197], '4': [332545]}),
#  "What is on the boy's back walking?": defaultdict(list,
#              {'backpack': [262197]}),
#  'How many modes of transportation are depicted?': defaultdict(list,
#              {'0': [262197], '2': [563067]}),
#  'What color is the building?': defaultdict(list,
#              {'brown': [262197,
#                524577,
#                140456,
#                404534,
#                405007,
#                150413,
#                311510,
#                42471,
#                310669,
#                438232,
#                329940,
#                206550,
#                79588,
#                486974,
#                225574,
#                247806,
#                512511],
#               'gray': [525058, 525619, 434159, 120473, 471578, 230615, 513497],
#               'yellow': [525371, 351589, 24629, 549361, 234691],
#               'pink': [398454],
#               'red': [399538,
#                283097,
#                156503,
#                301817,
#                173125,
#                566414,
#                304396,
#                306264,
#                49097,
#                191501,
#                207675],
#               'white': [8350,
#                277046,
#                412094,
#                547136,
#                287970,
#                49733,
#                54358,
#                189885,
#                336587,
#                490890,
#                301107,
#                365623,
#                105786,
#                242411,
#                253520,
#                517443,
#                388267,
#                257971],
#               'tan': [408894, 415748, 578786],
#               'orange': [23671, 93791],
#               'black': [330676],
#               'purple': [203580],
#               'blue': [171678],
#               'green': [151000]}),
#  'Is it still snowing in the picture?': defaultdict(list,
#              {'yes': [393271], 'no': [317049]}),
#  'Does this appear to be a photo of multiple exposures of the black clad snowboarder?': defaultdict(list,
#              {'yes': [393271], 'no': [310998]}),
#  'How many people can you see in the picture?': defaultdict(list,
#              {'8': [393271], '1': [200563, 236432], '3': [474953]}),
#  'Is this an adult party?': defaultdict(list,
#              {'no': [262200], 'yes': [276552]}),
#  'What is being celebrated?': defaultdict(list,
#              {'birthday': [262200,
#                433883,
#                448151,
#                318455,
#                71737,
#                346703,
#                106272,
#                251794],
#               'halloween': [151657],
#               'wedding': [556873, 314112],
#               'baby shower': [446958],
#               'christmas': [114184]}),
#  'Who is in front of the cake with candles?': defaultdict(list,
#              {'boy': [262200], 'girl': [213599]}),
#  'What is this vehicle?': defaultdict(list,
#              {'train': [393274, 450324, 468499, 344205, 113570],
#               'motorcycle': [395324, 21711],
#               'van': [528136],
#               'airplane': [537427],
#               'bus': [17207],
#               'dump truck': [159451],
#               'jeep': [292188],
#               'boat': [31599, 386370],
#               'truck': [188522, 174004],
#               'moped': [196415],
#               'fire truck': [357578]}),
#  'Can you see the hook up for the train?': defaultdict(list,
#              {'no': [393274], 'yes': [519673]}),
#  'Is this train at the station?': defaultdict(list,
#              {'yes': [393274], 'no': [208648]}),
#  'What is cast?': defaultdict(list,
#              {'shadow': [393274,
#                265050,
#                402798,
#                285742,
#                272953,
#                351787,
#                277498,
#                278977,
#                153011,
#                30668,
#                298261,
#                298316,
#                46269,
#                316526,
#                60347,
#                325885,
#                330932,
#                331569,
#                333656,
#                318146,
#                337375,
#                34500,
#                209222,
#                212292,
#                212675,
#                122927,
#                344832,
#                213951,
#                215998,
#                216910,
#                223699,
#                355143,
#                224848,
#                227073,
#                230008,
#                365540,
#                235252,
#                372471,
#                368559,
#                246004,
#                247609,
#                248297,
#                254074,
#                519744,
#                521282],
#               'giraffes': [134119],
#               'sun': [9214, 316396],
#               'bus': [142774, 227893],
#               'umbrellas': [275161],
#               'train': [275791, 113570],
#               'nothing': [277689, 409630, 282046],
#               'fishing line': [149017],
#               'sunny': [150538, 341620],
#               'sky': [282366],
#               'zebras': [155355],
#               'kite': [551910],
#               'woman': [551974],
#               'shadows': [290248,
#                311083,
#                323468,
#                350694,
#                360661,
#                370999,
#                377352,
#                384258],
#               'frisbee': [159854, 563964, 112342, 261036],
#               'motorcycle': [293245, 317254, 348092],
#               'motorcycles': [355040],
#               'horse': [101828, 370709],
#               'bikes': [307892],
#               'cow': [316041],
#               'birds and plane': [467475],
#               'bat': [214257],
#               'ball': [226498, 237071],
#               'zebra': [231942],
#               'food': [250901],
#               'vegetables': [382210],
#               'elephants': [391144]}),
#  'What is the background metal structure?': defaultdict(list,
#              {'platform': [393274], 'electrical tower': [318095]}),
#  'Is there smoke coming out of the train?': defaultdict(list,
#              {'no': [393274], 'yes': [505638]}),
#  'Is this station in a rural setting?': defaultdict(list,
#              {'yes': [393274], 'no': [146825]}),
#  'Are the train tracks clear?': defaultdict(list,
#              {'yes': [393274], 'no': [495349]}),
#  'What type of cat is this?': defaultdict(list,
#              {'tabby': [131131,
#                398489,
#                145448,
#                36484,
#                167802,
#                56373,
#                469424,
#                473555,
#                238602,
#                283286],
#               'ceramic': [408235],
#               'siamese': [423513],
#               'calico': [561393],
#               'housecat': [38938],
#               'black': [315467, 318571, 198641, 74268],
#               'gray': [84124],
#               'white': [479440],
#               'house cat': [226400],
#               'alley cat': [501788],
#               'domestic': [371117],
#               'black and white': [507301],
#               'not cat': [508899]}),
#  'What is written lg in the pic?': defaultdict(list, {'monitor': [131131]}),
#  'How many cats are in the image?': defaultdict(list,
#              {'2': [131131], '1': [98839]}),
#  'Are there any tour buses?': defaultdict(list,
#              {'no': [393277], 'yes': [176374]}),
#  "What's the statue of?": defaultdict(list,
#              {'clock tower': [393277], 'man': [260927]}),
#  'Are all three cars facing the same direction?': defaultdict(list,
#              {'no': [393277, 508247]}),
#  'What year is the car?': defaultdict(list,
#              {'2010': [393277], 'old': [451202], '1980': [58851]}),
#  'What color is the sky?': defaultdict(list,
#              {'blue': [393277,
#                132024,
#                263679,
#                415413,
#                264268,
#                2532,
#                153392,
#                134722,
#                22498,
#                397628,
#                528977,
#                136595,
#                5690,
#                268943,
#                531585,
#                307243,
#                482062,
#                402570,
#                271825,
#                10684,
#                536110,
#                405191,
#                536444,
#                274864,
#                537668,
#                144935,
#                538394,
#                276731,
#                14874,
#                145956,
#                147904,
#                279024,
#                541887,
#                541952,
#                279984,
#                411630,
#                282046,
#                413852,
#                414133,
#                283495,
#                283945,
#                284354,
#                22396,
#                419074,
#                548939,
#                25252,
#                550084,
#                27208,
#                27390,
#                27441,
#                420710,
#                475917,
#                28285,
#                423125,
#                357303,
#                556240,
#                425634,
#                425948,
#                295340,
#                164555,
#                165419,
#                427649,
#                167337,
#                167668,
#                167725,
#                202935,
#                170293,
#                563653,
#                39760,
#                170914,
#                173057,
#                173138,
#                306421,
#                175942,
#                308974,
#                160728,
#                29680,
#                464207,
#                179711,
#                311068,
#                573843,
#                182541,
#                576966,
#                446455,
#                53542,
#                53956,
#                447242,
#                316795,
#                186788,
#                187745,
#                58851,
#                59171,
#                429697,
#                59328,
#                9891,
#                321805,
#                60125,
#                322719,
#                468935,
#                454577,
#                192714,
#                447279,
#                63549,
#                457131,
#                326593,
#                326798,
#                50165,
#                196660,
#                196681,
#                458953,
#                328111,
#                197199,
#                198271,
#                330387,
#                462105,
#                463588,
#                70761,
#                464312,
#                447553,
#                202573,
#                579982,
#                405530,
#                205232,
#                74460,
#                336771,
#                468178,
#                339022,
#                208423,
#                253223,
#                209062,
#                210228,
#                79837,
#                342006,
#                474215,
#                145020,
#                345930,
#                477820,
#                477955,
#                215826,
#                347163,
#                216398,
#                216739,
#                217156,
#                349575,
#                87588,
#                351621,
#                90373,
#                484754,
#                92109,
#                486233,
#                225177,
#                356490,
#                226498,
#                226634,
#                228197,
#                360610,
#                98523,
#                360926,
#                361382,
#                100087,
#                410221,
#                239093,
#                233994,
#                234766,
#                279596,
#                366950,
#                236182,
#                367680,
#                367747,
#                501443,
#                502456,
#                503724,
#                501237,
#                247306,
#                216457,
#                382670,
#                382683,
#                251736,
#                254104,
#                255096,
#                517443,
#                125590,
#                391415,
#                522713,
#                391889,
#                129812,
#                130527,
#                261777,
#                130791],
#               'gray': [1029,
#                264238,
#                267710,
#                268371,
#                6306,
#                438017,
#                269682,
#                403065,
#                272736,
#                142774,
#                539310,
#                483266,
#                278222,
#                152192,
#                152870,
#                416072,
#                552153,
#                553339,
#                29197,
#                242870,
#                31748,
#                32941,
#                35897,
#                560675,
#                560880,
#                430760,
#                563040,
#                432898,
#                433483,
#                173544,
#                436280,
#                437738,
#                175994,
#                308193,
#                46603,
#                308785,
#                444126,
#                8646,
#                183114,
#                445295,
#                315191,
#                184789,
#                578967,
#                317070,
#                523241,
#                56891,
#                189248,
#                452721,
#                59743,
#                322143,
#                191138,
#                191425,
#                50177,
#                329614,
#                200274,
#                120977,
#                203846,
#                336587,
#                469824,
#                515422,
#                474862,
#                474906,
#                475466,
#                347377,
#                349616,
#                219440,
#                219589,
#                451915,
#                517523,
#                485201,
#                359020,
#                229747,
#                100098,
#                100404,
#                367706,
#                138975,
#                117725,
#                246883,
#                248793,
#                249277,
#                249785,
#                382115,
#                384348,
#                125072,
#                125286,
#                283217,
#                391006,
#                391392,
#                261155],
#               'orange': [266070, 326582, 102637],
#               'black': [402662,
#                272323,
#                167082,
#                320249,
#                459342,
#                477805,
#                487843,
#                379014,
#                391648],
#               'purple': [274084, 158015],
#               'white': [330110,
#                161161,
#                299481,
#                574010,
#                75560,
#                338325,
#                207853,
#                342322,
#                350974,
#                482477,
#                98721,
#                361142,
#                367860,
#                110997,
#                508165,
#                516476,
#                125572],
#               'yellow': [407821, 575896],
#               'pink': [293768, 296265, 308907, 67886],
#               'blue and orange': [561042]}),
#  'What time is it on the clock?': defaultdict(list,
#              {'8:35': [393277],
#               '12:12': [219920],
#               '1:05': [145956],
#               '9:55': [540789, 505663],
#               '1:30': [148614, 125201],
#               '8:27': [283432],
#               '3:20': [25252],
#               '3:30': [29019],
#               '11:05': [553588],
#               '6:45': [294163],
#               '8:05': [561412, 386313],
#               '11:50': [430760, 42182],
#               '10:07': [169700],
#               '3:15': [563731, 331282, 470909],
#               '2:10': [437028],
#               '11:54': [455352],
#               '12:54': [65231],
#               '12:25': [202797, 518234],
#               '9:20': [208585],
#               '5:10': [342479],
#               '1:25': [345869],
#               '8:20': [92050],
#               '3:50': [357194],
#               '11:20': [357265],
#               '8:50': [358302],
#               '8:56': [230721],
#               '12:52': [363100],
#               '7:55': [495894],
#               '11:28': [500446],
#               '1:10': [244111],
#               '8:00': [517443]}),
#  'Are there a lot of people milling around?': defaultdict(list,
#              {'no': [393277], 'yes': [41998]}),
#  'Is the building large?': defaultdict(list, {'yes': [393277, 28002]}),
#  'How is the weather?': defaultdict(list,
#              {'cloudy': [393277,
#                137677,
#                547431,
#                417085,
#                50100,
#                312951,
#                341389,
#                474906,
#                475798,
#                58157,
#                483375,
#                318561],
#               'clear': [265063,
#                550365,
#                288890,
#                42968,
#                580041,
#                234153,
#                502456,
#                374530],
#               'sunny': [405216,
#                144935,
#                558834,
#                316534,
#                163412,
#                478212,
#                228541,
#                229234,
#                104002,
#                499268,
#                372914],
#               'rainy': [281602, 287366, 107226],
#               'snowy': [545288],
#               'foggy': [565813, 517612],
#               'snowing': [490638],
#               'cold': [236308, 506201]}),
#  'What color is the building the background?': defaultdict(list,
#              {'gray': [393277], 'red': [40259]}),
#  'What time is it?': defaultdict(list,
#              {'8:35': [393277, 342006, 359110, 85004],
#               '11:10': [524577, 338, 198661],
#               '2:45': [153094, 539298, 280530, 556240, 469824, 216419],
#               'no time': [423396],
#               '10': [263292],
#               '4:45': [263412, 132499],
#               '12:44': [394715],
#               '10:05': [132861, 435257, 581632],
#               '3:24': [395210],
#               'nighttime': [415413],
#               '6:56': [131431, 111435],
#               '4:40': [2529, 269419, 300855, 305253, 310560, 334073],
#               '6:00': [395801, 74209, 254119, 517417],
#               '9:50': [264730, 217301],
#               '1:00': [131504, 435709, 325505, 338592],
#               '12:32': [3084],
#               '2:35': [3149, 11182, 430287, 338591, 357944],
#               '12:05': [396676],
#               'evening': [266151,
#                560218,
#                201993,
#                480225,
#                90373,
#                484751,
#                499950,
#                512421],
#               '2:12': [4157, 500940],
#               '5:30': [266385, 245173, 185712, 324492],
#               '5:50': [5758, 157756, 292804, 330818, 246666],
#               '6:12': [530461, 43635],
#               '11:20': [6211, 150024, 456178, 218587, 496102, 256301],
#               '11:43': [6527],
#               '5:42': [269600],
#               '12:25': [138755, 415646, 518234],
#               '5:45': [269949, 437110, 50232, 182424, 324161, 202622],
#               '1:08': [132373, 407825],
#               '5:00': [401240, 476628],
#               '2:30': [8218, 9274, 57725],
#               '6:20': [8498, 535997],
#               '4:04': [139749],
#               '7:35': [139843, 234691, 381699],
#               '12:12': [219920],
#               '1:10': [271068, 452881, 196118, 120473, 249838],
#               '2:26': [271076, 388854],
#               '12:50': [9172, 25457, 451095],
#               '8:09': [533464],
#               '1:55': [533508, 304484],
#               '12:00': [533537, 40711, 219329],
#               '2:10': [9791, 449043, 78312, 387833],
#               '12:43': [140929],
#               '12:40': [272080, 406959, 445372, 473896, 234535],
#               '8:04': [273196],
#               '9:55': [535501, 505663],
#               '20:30': [142744],
#               '12:10': [417055, 283516, 106563],
#               '5:40': [264209, 294305],
#               'night': [143560, 47886, 205573, 341635, 379014],
#               '11:55': [274864,
#                158993,
#                160108,
#                292347,
#                162914,
#                455352,
#                245430],
# ...
#               'apples': [473406],
#               'pork and broccoli': [499594],
#               'vegetables': [217397]}),
#  'Is that a fork or knife sticking out of the mixture?': defaultdict(list,
#              {'fork': [393682], 'knife': [442724]}),
#  'Are they doing the same sport?': defaultdict(list,
#              {'yes': [131539], 'no': [462805]}),
#  'Did these people run into each other?': defaultdict(list,
#              {'no': [131539], 'yes': [462805]}),
#  'Has this area been windy lately?': defaultdict(list,
#              {'yes': [131539, 85144]}),
#  'Is this the morning?': defaultdict(list, {'yes': [131539, 478977]}),
#  'Are these skiers using a chair lift?': defaultdict(list,
#              {'no': [131539, 257136]}),
#  "What color is the closest skier's jacket?": defaultdict(list,
#              {'red': [131539], 'gray': [257136]}),
#  'Are they having fun?': defaultdict(list,
#              {'yes': [131539,
#                170181,
#                437290,
#                455555,
#                205370,
#                85144,
#                88286,
#                122281],
#               'no': [64902, 147025, 100723, 247259]}),
#  'Are there any clouds in the sky?': defaultdict(list,
#              {'no': [131539,
#                264268,
#                133928,
#                328661,
#                405104,
#                411559,
#                547783,
#                550103,
#                32715,
#                93405,
#                298440,
#                431521,
#                159537,
#                43795,
#                50482,
#                51685,
#                314313,
#                185590,
#                318426,
#                193884,
#                456197,
#                196681,
#                535608,
#                463785,
#                209989,
#                343187,
#                84474,
#                222322,
#                212842,
#                362092,
#                367452,
#                237568,
#                244246,
#                380552,
#                255096,
#                256906,
#                522478],
#               'yes': [1374,
#                266070,
#                531349,
#                372706,
#                143541,
#                274957,
#                147921,
#                267225,
#                427612,
#                166391,
#                28377,
#                41246,
#                174671,
#                306229,
#                314493,
#                577512,
#                447948,
#                193889,
#                56092,
#                451144,
#                60449,
#                62985,
#                457691,
#                578984,
#                207797,
#                340472,
#                471578,
#                515565,
#                215408,
#                480133,
#                480470,
#                95375,
#                100234,
#                322831,
#                496554,
#                238980,
#                108243,
#                108528,
#                505792,
#                116279,
#                119132]}),
#  'Is it summer?': defaultdict(list,
#              {'no': [131539,
#                3926,
#                566096,
#                43202,
#                577310,
#                314709,
#                316658,
#                381576,
#                296730,
#                485509,
#                100245,
#                232646,
#                365386,
#                366178,
#                40681,
#                511852,
#                122314,
#                123137,
#                127911],
#               'yes': [134074,
#                147921,
#                283432,
#                570386,
#                572665,
#                320641,
#                192091,
#                333412,
#                203370,
#                478857,
#                216790,
#                224329,
#                363991,
#                242610,
#                519399]}),
#  'Are there any trees visible?': defaultdict(list,
#              {'no': [131539, 234914],
#               'yes': [534565, 560440, 234938, 252280]}),
#  'What are the people doing?': defaultdict(list,
#              {'skiing': [131539,
#                531020,
#                143275,
#                21979,
#                562818,
#                301563,
#                173204,
#                45729,
#                573686,
#                447465,
#                450570,
#                163260,
#                202981,
#                465836,
#                338108,
#                78060,
#                341389,
#                85813,
#                17365,
#                236308,
#                502998,
#                389738,
#                129982],
#               'walking': [263011,
#                5325,
#                403995,
#                542205,
#                282553,
#                551199,
#                267225,
#                499374,
#                56983,
#                219558,
#                222548,
#                106677,
#                375286,
#                116083,
#                388085],
#               'talking on phone': [174989],
#               'riding scooter': [263664],
#               'playing wii': [1626,
#                400238,
#                540473,
#                16593,
#                155478,
#                156924,
#                288041,
#                39718,
#                172946,
#                499095,
#                573320,
#                182155,
#                454751,
#                67207,
#                218855,
#                230561,
#                82688,
#                367116,
#                376679,
#                115146],
#               'surfing': [2171,
#                6417,
#                403584,
#                92190,
#                410885,
#                423125,
#                175825,
#                315249,
#                189248,
#                84984,
#                364256,
#                105996,
#                110877,
#                544574,
#                516318],
#               'flying kite': [264423, 413522, 294182, 62985, 195863, 359436],
#               'playing tennis': [395665, 390902],
#               'cooking': [69914, 89099, 150843, 32932],
#               'playing': [133933, 527733, 457901, 217546, 222559],
#               'horseback riding': [134856],
#               'playing baseball': [397008, 543620, 232160, 382350],
#               'tennis': [528201, 483227, 501281],
#               'standing': [528257,
#                279895,
#                46975,
#                444324,
#                213280,
#                347506,
#                99518,
#                375450,
#                115571],
#               'eating': [398222, 81812, 122962, 69140, 372654, 129765],
#               'posing': [5193, 412362, 155774, 170267, 105052, 125873],
#               'flying kites': [306914,
#                279558,
#                153279,
#                293200,
#                163117,
#                570756,
#                462755,
#                470766,
#                218189,
#                487612],
#               'boating': [69887],
#               'texting': [534162, 420120, 203372],
#               'rowing': [220215],
#               'snowboarding': [143107, 173514, 312772, 213465],
#               'feeding giraffes': [536720],
#               'fishing': [13132],
#               'gaming': [407121],
#               'skateboarding': [145295, 160195, 44800, 177567, 509826, 253341],
#               'watching baseball': [276580],
#               'typing': [539694],
#               'waiting for bus': [279521],
#               'paying for parking': [281102],
#               'jumping': [547258],
#               'crossing street': [553912],
#               'celebrating': [32001, 259761],
#               'boogie boarding': [426238],
#               'celebrating birthday': [561013],
#               'sitting': [561780, 562292, 334083, 375440, 520778, 480416],
#               'not sure': [435012],
#               'frisbee': [307073],
#               'reading': [569314],
#               'singing': [177953],
#               'playing frisbee': [46882, 64059, 200234],
#               'drinking coffee': [48684],
#               'driving': [315601, 259452],
#               'watching tennis': [57387],
#               'sleeping': [303069],
#               'working': [188804, 232488],
#               'talking': [189305, 468953, 563605, 386424],
#               'cycling': [320641],
#               'riding': [452721],
#               'taking pictures': [323827, 213978, 151000],
#               'using computer': [403619],
#               'riding carriage': [455956],
#               'shaking hands': [467107],
#               'riding bikes': [75001, 492077, 241291, 511777],
#               'greeting': [77222],
#               'waiting': [253455, 218891],
#               'watching': [212080, 480133],
#               'playing soccer': [476233, 103485],
#               'learning': [83036, 220607],
#               'cross country skiing': [478977],
#               'watching tv': [93120],
#               'untangling kite string': [224675],
#               'cutting cake': [94194],
#               'water skiing': [358903],
#               'listening to music': [227901],
#               'swimming': [100081],
#               'drinking': [236023],
#               'boarding plane': [368541],
#               'riding elephant': [61943],
#               'moving': [109819],
#               'waiting in line': [158849],
#               'selling food': [381608],
#               'paddle boarding': [121570]}),
#  'Is that an airplane in the image?': defaultdict(list,
#              {'yes': [472], 'no': [5601]}),
#  'Is the island inhabited?': defaultdict(list, {'no': [472], 'yes': [303603]}),
#  'Are the blue patches water?': defaultdict(list,
#              {'yes': [472], 'no': [109206]}),
#  'How big is the plane?': defaultdict(list, {'large': [472], 'big': [109206]}),
#  'Is the water rippling?': defaultdict(list, {'no': [472], 'yes': [30113]}),
#  'Is this good weather for their flight?': defaultdict(list,
#              {'yes': [472], 'no': [552153]}),
#  'What color are the checkers on the wall?': defaultdict(list,
#              {'red and white': [262617]}),
#  'How many pizza slices are there total?': defaultdict(list,
#              {'14': [262617], '8': [472164]}),
#  'What is sold here?': defaultdict(list,
#              {'pizza': [262617],
#               'vegetables': [242368],
#               'fruit': [294451],
#               'bananas': [50149],
#               'nothing': [463498]}),
#  "What is on the boy's hand?": defaultdict(list, {'glove': [474]}),
#  'What color is the boys shirt on the shoulder?': defaultdict(list,
#              {'pink': [474], 'purple': [401244]}),
#  'Is there grass?': defaultdict(list,
#              {'yes': [474, 136008, 458467, 76962, 96618, 107542],
#               'no': [209664, 512220, 386967, 518729, 129547]}),
#  'How many cell phones are on the table?': defaultdict(list,
#              {'4': [393692],
#               '2': [39053, 226069],
#               '3': [568367],
#               '0': [570465],
#               '1': [318174]}),
#  'Is the lamp on?': defaultdict(list,
#              {'yes': [393692,
#                143483,
#                537513,
#                281582,
#                413600,
#                31280,
#                560368,
#                569059,
#                572331,
#                573320,
#                50025,
#                54334,
#                203479,
#                79472,
#                124659,
#                228418,
#                109797],
#               'no': [394133,
#                532761,
#                1503,
#                415196,
#                294992,
#                297620,
#                178941,
#                179045,
#                60596,
#                79686,
#                87885,
#                90839,
#                248111,
#                260486]}),
#  "Does the kitty think it's going to rain?": defaultdict(list,
#              {'no': [262626, 112719]}),
#  'Is the kitty on the umbrella?': defaultdict(list,
#              {'no': [262626], 'yes': [112719]}),
#  'What animal is on the bed?': defaultdict(list,
#              {'cat': [262626, 54340, 118546],
#               'dog': [170898],
#               'alligator': [54540],
#               'bear': [255827]}),
#  'What is the picture on the smallest pillow?': defaultdict(list,
#              {'flowers': [262626], 'circles': [575079]}),
#  'What color are most of the pillows?': defaultdict(list,
#              {'blue': [262626], 'white': [255827]}),
#  'Is the skier wearing goggles?': defaultdict(list,
#              {'yes': [131556, 540207, 509223], 'no': [275448]}),
#  'Is this skier using poles?': defaultdict(list,
#              {'yes': [131556], 'no': [52267]}),
#  'What is the person standing on?': defaultdict(list,
#              {'skis': [131556, 263223],
#               'trolley': [110784],
#               'skateboard': [281072, 358664, 244151, 41574],
#               'surfboard': [544334, 240275, 433845, 369667],
#               'tennis court': [23121],
#               'snow': [113233],
#               'rocks': [551921],
#               'cement': [429290],
#               'floor': [312889],
#               'snowboard': [213465],
#               'bench': [29397],
#               'street': [98431],
#               'ground': [119773],
#               'pipe': [128675]}),
#  'Does it look like a piece has been taken from the plate yet?': defaultdict(list,
#              {'no': [131557], 'yes': [84493]}),
#  'What topping are on the pizza?': defaultdict(list,
#              {'mushrooms': [131557], 'lettuce': [189243]}),
#  'What pattern is on the plate?': defaultdict(list,
#              {'stripes': [131557], 'floral': [149469]}),
#  'Is there gluten in this pizza?': defaultdict(list,
#              {'yes': [131557, 342933]}),
#  'What are the sources of protein on this pizza?': defaultdict(list,
#              {'cheese': [131557], 'pepperoni and cheese': [35146]}),
#  'What is the white substance on the plate?': defaultdict(list,
#              {'cheese': [131557], 'rice': [205716]}),
#  'Are there red peppers on the pizza?': defaultdict(list,
#              {'no': [131557], 'yes': [263723]}),
#  'Is it a deep dish pizza?': defaultdict(list,
#              {'no': [131557], 'yes': [128059]}),
#  'Are there bicycles?': defaultdict(list,
#              {'no': [486, 485822], 'yes': [67823, 226903]}),
#  'Has the wall been painted recently?': defaultdict(list,
#              {'no': [486], 'yes': [262682]}),
#  'Where is the strainer?': defaultdict(list, {'counter': [486]}),
#  'What material is the counter made of?': defaultdict(list,
#              {'wood': [486, 274017],
#               'granite': [133515],
#               'formica': [226903]}),
#  'According to the sign what type of bus is this?': defaultdict(list,
#              {'tour bus': [524775], 'magic bus': [237254]}),
#  'What color is the words bus and boat tour?': defaultdict(list,
#              {'red': [524775]}),
#  'How many people can fit in the 2 buses?': defaultdict(list,
#              {'100': [524775, 423617]}),
#  'What type of bus is seen?': defaultdict(list,
#              {'tour bus': [524775], 'magic bus': [237254]}),
#  'Where is the license plate?': defaultdict(list,
#              {'front of bus': [524775],
#               'front': [12230],
#               'back of car': [91283],
#               'back': [364266],
#               'bottom center': [508087],
#               'front bumper': [42008]}),
#  'What colors are the bus?': defaultdict(list,
#              {'yellow and white': [524775],
#               'red and white': [275843, 292663],
#               'blue and white': [287305],
#               'orange and blue': [78696],
#               'yellow and red': [355817],
#               'yellow and black': [106508],
#               'red': [113828],
#               'yellow and gray': [38357],
#               'blue and yellow': [124798]}),
#  'What company does the bus belong to?': defaultdict(list,
#              {'forth bridges': [524775], 'citylink': [55167]}),
#  'How fast do these buses drive?': defaultdict(list,
#              {'30 mph': [524775], 'slow': [316063]}),
#  'Is the battery going to bunt?': defaultdict(list,
#              {'yes': [488], 'no': [192670]}),
#  'What game is been played?': defaultdict(list,
#              {'baseball': [488, 180336, 188445],
#               'tennis': [77591, 504415],
#               'soccer': [476233]}),
#  ...}

# %%
train_qud_data = json.load(open("./data/vqa/train_qud_data.json"))

# %%
train_image_id_to_cap = json.load(open("./data/vqa/train_image_id_to_cap.json"))

# %%
def display_qud_captions(qud_data, image_id_to_cap, ranges):
    # we default to 1st caption for display
    
    qud_data_list = list(qud_data.items())
    for idx in ranges:
        ex = qud_data_list[idx]
        print("Q: ", ex[0])
        for k, vs in ex[1].items():
            print("Answer: ", k)
            for v in vs:
                print("Image ID", v, "Caption: ", image_id_to_cap[str(v)][0])
        print()

# %%
display_qud_captions(train_qud_data, train_image_id_to_cap, range(10))
